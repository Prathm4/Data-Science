# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\Vikas Salunke\Desktop\Data Science\Fraud_check.csv")

# %%
df.head()
# Out:
#   Undergrad Marital.Status  Taxable.Income  City.Population  Work.Experience  \
# 0        NO         Single           68833            50047               10
# 1       YES       Divorced           33700           134075               18
# 2        NO        Married           36925           160205               30
# 3       YES         Single           50190           193264               15
# 4        NO        Married           81002            27533               28
#
#   Urban
# 0   YES
# 1   YES
# 2   YES
# 3   YES
# 4    NO

# %%
df=pd.get_dummies(df,columns=['Undergrad','Marital.Status','Urban'], drop_first=True)

# %%
#Creating new cols TaxInc and dividing 'Taxable.Income' cols on the basis of [10002,30000,99620] for Risky and Good
df["TaxInc"] = pd.cut(df["Taxable.Income"], bins = [10002,30000,99620], labels = ["Risky", "Good"])

# %%
#After creation of new col. TaxInc also made its dummies var concating right side of df
df = pd.get_dummies(df,columns = ["TaxInc"],drop_first=True)

# %%
#Viewing buttom 20 observations
df.tail(20)
# Out:
#      Taxable.Income  City.Population  Work.Experience  Undergrad_YES  \
# 580           31721           123335                1              1
# 581           31085            57473               10              1
# 582           84931            32907               12              1
# 583           69036            28874               19              0
# 584           42679           155684                4              0
# 585           84557           137622                2              0
# 586           54126           106230               30              1
# 587           87685           154677               26              0
# 588           85076            93242               27              1
# 589           31633            30774               10              1
# 590           43018            85195               14              0
# 591           27394           132859               18              1
# 592           68152            75143               16              1
# 593           84775           131963               10              0
# 594           47364            97526                9              0
# 595           76340            39492                7              1
# 596           69967            55369                2              1
# 597           47334           154058                0              0
# 598           98592           180083               17              1
# 599           96519           158137               16              0
#
#      Marital.Status_Married  Marital.Status_Single  Urban_YES  TaxInc_Good
# 580                       0                      0          1            1
# 581                       0                      0          1            1
# 582                       1                      0          1            1
# 583                       1                      0          0            1
# 584                       0                      0          1            1
# 585                       0                      1          1            1
# 586                       0                      1          0            1
# 587                       0                      1          1            1
# 588                       1                      0          1            1
# 589                       1                      0          0            1
# 590                       1                      0          1            1
# 591                       0                      1          1            0
# 592                       0                      1          0            1
# 593                       0                      0          1            1
# 594                       1                      0          1            1
# 595                       0                      0          1            1
# 596                       0                      0          1            1
# 597                       0                      0          1            1
# 598                       1                      0          0            1
# 599                       0                      0          0            1

# %%
# Normalization function 
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return (x)

# %%
# Normalized data frame (considering the numerical part of data)
df_norm = norm_func(df.iloc[:,1:])
df_norm.tail(20)
# Out:
#      City.Population  Work.Experience  Undergrad_YES  Marital.Status_Married  \
# 580         0.560670         0.033333            1.0                     0.0
# 581         0.182150         0.333333            1.0                     0.0
# 582         0.040966         0.400000            1.0                     1.0
# 583         0.017787         0.633333            0.0                     1.0
# 584         0.746585         0.133333            0.0                     0.0
# 585         0.642780         0.066667            0.0                     0.0
# 586         0.462365         1.000000            1.0                     0.0
# 587         0.740797         0.866667            0.0                     0.0
# 588         0.387721         0.900000            1.0                     1.0
# 589         0.028707         0.333333            1.0                     1.0
# 590         0.341473         0.466667            0.0                     1.0
# 591         0.615406         0.600000            1.0                     0.0
# 592         0.283703         0.533333            1.0                     0.0
# 593         0.610256         0.333333            0.0                     0.0
# 594         0.412341         0.300000            0.0                     1.0
# 595         0.078811         0.233333            1.0                     0.0
# 596         0.170058         0.066667            1.0                     0.0
# 597         0.737240         0.000000            0.0                     0.0
# 598         0.886810         0.566667            1.0                     1.0
# 599         0.760683         0.533333            0.0                     0.0
#
#      Marital.Status_Single  Urban_YES  TaxInc_Good
# 580                    0.0        1.0          1.0
# 581                    0.0        1.0          1.0
# 582                    0.0        1.0          1.0
# 583                    0.0        0.0          1.0
# 584                    0.0        1.0          1.0
# 585                    1.0        1.0          1.0
# 586                    1.0        0.0          1.0
# 587                    1.0        1.0          1.0
# 588                    0.0        1.0          1.0
# 589                    0.0        0.0          1.0
# 590                    0.0        1.0          1.0
# 591                    1.0        1.0          0.0
# 592                    1.0        0.0          1.0
# 593                    0.0        1.0          1.0
# 594                    0.0        1.0          1.0
# 595                    0.0        1.0          1.0
# 596                    0.0        1.0          1.0
# 597                    0.0        1.0          1.0
# 598                    0.0        0.0          1.0
# 599                    0.0        0.0          1.0

# %%
# Declaring features & target
X = df_norm.drop(['TaxInc_Good'], axis=1)
y = df_norm['TaxInc_Good']

# %%
from sklearn.model_selection import train_test_split

# %%
# Splitting data into train & test
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size=0.5, random_state=0)

# %%
#Choosing RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
print('Train accuracy: {}'.format(forest_new.score(Xtrain, ytrain)))
print('Test accuracy: {}'.format(forest_new.score(Xtest, ytest)))
# Out:
# Train accuracy: 0.8233333333333334
# Test accuracy: 0.77

# %%
# Creating new model testing with new parameters
forest_new = RandomForestClassifier(n_estimators=100,max_depth=10,min_samples_split=20,criterion='gini')  # n_estimators is the number of decision trees
forest_new.fit(Xtrain, ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=10, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=20,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print('Train accuracy: {}'.format(forest_new.score(Xtrain, ytrain)))
print('Test accuracy: {}'.format(forest_new.score(Xtest, ytest)))
# Out:
# Train accuracy: 0.8233333333333334
# Test accuracy: 0.7666666666666667
